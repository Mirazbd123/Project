# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

# %%
def get_access(url):
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})
    response = requests.get(url,headers=HEADERS)
    soup = bs(response.content, "html.parser")
    return soup

soup = get_access("https://www.amazon.com/s?k=gaming+laptops&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&ref=nb_sb_noss")
# print(soup)

# %%
#finding the link of next button
link_list = []
while True:
    link_next = soup.find_all('a' , attrs={'class' : 's-pagination-item s-pagination-next s-pagination-button s-pagination-separator'})
    link_list.append("https://www.amazon.com"+str(link_next[0].get('href')))
    next_url = "https://www.amazon.com"+str(link_next[0].get('href'))
    print(next_url)

    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})
    response = requests.get(next_url,headers=HEADERS)
    soup = bs(response.content, "html.parser")

# %%
link_list
# Out:
# ['https://www.amazon.com/s?k=gaming+laptops&page=2&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195217&ref=sr_pg_1',
#  'https://www.amazon.com/s?k=gaming+laptops&page=3&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195219&ref=sr_pg_2',
#  'https://www.amazon.com/s?k=gaming+laptops&page=4&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195222&ref=sr_pg_3',
#  'https://www.amazon.com/s?k=gaming+laptops&page=5&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195225&ref=sr_pg_4',
#  'https://www.amazon.com/s?k=gaming+laptops&page=6&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195226&ref=sr_pg_5',
#  'https://www.amazon.com/s?k=gaming+laptops&page=7&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195228&ref=sr_pg_6',
#  'https://www.amazon.com/s?k=gaming+laptops&page=8&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195230&ref=sr_pg_7',
#  'https://www.amazon.com/s?k=gaming+laptops&page=9&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195231&ref=sr_pg_8',
#  'https://www.amazon.com/s?k=gaming+laptops&page=10&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195233&ref=sr_pg_9',
#  'https://www.amazon.com/s?k=gaming+laptops&page=11&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195235&ref=sr_pg_10',
#  'https://www.amazon.com/s?k=gaming+laptops&page=12&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195237&ref=sr_pg_11',
#  'https://www.amazon.com/s?k=gaming+laptops&page=13&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195239&ref=sr_pg_12',
#  'https://www.amazon.com/s?k=gaming+laptops&page=14&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195240&ref=sr_pg_13',
#  'https://www.amazon.com/s?k=gaming+laptops&page=15&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195243&ref=sr_pg_14',
#  'https://www.amazon.com/s?k=gaming+laptops&page=16&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195245&ref=sr_pg_15',
#  'https://www.amazon.com/s?k=gaming+laptops&page=17&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195247&ref=sr_pg_16',
#  'https://www.amazon.com/s?k=gaming+laptops&page=18&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195249&ref=sr_pg_17',
#  'https://www.amazon.com/s?k=gaming+laptops&page=19&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195253&ref=sr_pg_18',
#  'https://www.amazon.com/s?k=gaming+laptops&page=20&pf_rd_i=23508887011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=434db2ed-6d53-4c59-b173-e8cd550a2e4f&pf_rd_r=7BTE9CY4KJ3VPCC1W944&pf_rd_s=merchandised-search-5&pf_rd_t=101&qid=1720195256&ref=sr_pg_19']

# %%
product_name = []
price = []
rating = []
votes = []

for i in link_list:
    scrape_url = i
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})
    r = requests.get(scrape_url,headers=HEADERS)
    soup = bs(r.content, "html.parser")

    nameOfProduct = soup.find_all("span" , class_ = "a-size-medium a-color-base a-text-normal")
    for name in nameOfProduct:
        product_name.append(name.text)


    numOfRating = soup.find_all("span" , class_ = "a-icon-alt")
    for ratings in numOfRating:
        rating.append(ratings.text)


    numOfPrice = soup.find_all("span" , class_ = "a-price-whole")
    for prices in numOfPrice:
        price.append(prices.text)


    numOfVote = soup.find_all("span" , class_ = "a-size-base s-underline-text")
    for vote in numOfVote:
        votes.append(vote.text)

# %%
data = {"prodct_name":product_name, "price":price, "rating":rating, "votes":votes}

# %%
amazon_df = pd.DataFrame.from_dict(data)
amazon_df['prodct_name'].replace('', np.nan, inplace=True)
amazon_df = amazon_df.dropna(subset=['prodct_name'])
amazon_df.to_csv("amazon_data.csv", header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 amazon_df = pd.DataFrame.from_dict(data)
#       2 amazon_df['prodct_name'].replace('', np.nan, inplace=True)
#       3 amazon_df = amazon_df.dropna(subset=['prodct_name'])
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1917, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1911     raise ValueError(
#    1912         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1913         f"Got '{orient}' instead"
#    1914     )
#    1916 if orient != "tight":
# -> 1917     return cls(data, index=index, columns=columns, dtype=dtype)
#    1918 else:
#    1919     realdata = data["data"]
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
print(len(data['prodct_name']))
print(len(data['price']))
print(len(data['rating']))
print(len(data['votes']))
# Out:
# 376
# 302
# 261
# 239

# %%
price
# Out:
# ['1,719.',
#  '1,736.',
#  '1,692.',
#  '1,399.',
#  '597.',
#  '1,292.',
#  '1,399.',
#  '1,842.',
#  '790.',
#  '1,699.',
#  '1,849.',
#  '4,499.',
#  '1,129.',
#  '709.',
#  '597.',
#  '1,199.',
#  '2,120.',
#  '1,699.',
#  '299.',
#  '1,601.',
#  '529.',
#  '1,719.',
#  '1,736.',
#  '1,350.',
#  '771.',
#  '890.',
#  '2,249.',
#  '917.',
#  '699.',
#  '2,249.',
#  '1,599.',
#  '1,709.',
#  '1,899.',
#  '1,449.',
#  '1,089.',
#  '599.',
#  '1,329.',
#  '1,296.',
#  '1,562.',
#  '1,719.',
#  '1,736.',
#  '1,997.',
#  '3,999.',
#  '882.',
#  '1,120.',
#  '984.',
#  '1,299.',
#  '1,351.',
#  '1,249.',
#  '1,059.',
#  '1,167.',
#  '1,399.',
#  '1,234.',
#  '1,296.',
#  '1,719.',
#  '1,736.',
#  '1,196.',
#  '5,299.',
#  '849.',
#  '1,999.',
#  '1,399.',
#  '687.',
#  '1,399.',
#  '1,554.',
#  '849.',
#  '2,501.',
#  '729.',
#  '899.',
#  '974.',
#  '1,299.',
#  '529.',
#  '1,719.',
#  '1,736.',
#  '214.',
#  '1,049.',
#  '1,799.',
#  '720.',
#  '1,099.',
#  '4,799.',
#  '1,699.',
#  '799.',
#  '919.',
#  '1,499.',
#  '2,301.',
#  '3,107.',
#  '329.',
#  '1,234.',
#  '1,296.',
#  '392.',
#  '724.',
#  '1,649.',
#  '1,149.',
#  '569.',
#  '329.',
#  '1,699.',
#  '3,651.',
#  '717.',
#  '1,299.',
#  '2,051.',
#  '2,499.',
#  '582.',
#  '299.',
#  '998.',
#  '1,899.',
#  '2,299.',
#  '462.',
#  '1,736.',
#  '1,719.',
#  '1,736.',
#  '699.',
#  '1,749.',
#  '9,999.',
#  '956.',
#  '709.',
#  '2,301.',
#  '682.',
#  '1,809.',
#  '1,549.',
#  '3,429.',
#  '1,308.',
#  '1,099.',
#  '1,849.',
#  '1,296.',
#  '1,719.',
#  '1,736.',
#  '1,308.',
#  '1,099.',
#  '1,399.',
#  '1,999.',
#  '2,701.',
#  '4,199.',
#  '2,899.',
#  '3,299.',
#  '409.',
#  '2,099.',
#  '2,296.',
#  '2,599.',
#  '1,234.',
#  '1,296.',
#  '1,601.',
#  '1,719.',
#  '2,296.',
#  '1,899.',
#  '4,099.',
#  '5,919.',
#  '1,194.',
#  '1,199.',
#  '1,029.',
#  '1,849.',
#  '1,399.',
#  '2,899.',
#  '1,549.',
#  '1,410.',
#  '1,736.',
#  '1,234.',
#  '279.',
#  '1,299.',
#  '2,219.',
#  '3,049.',
#  '3,119.',
#  '3,049.',
#  '2,301.',
#  '1,554.',
#  '999.',
#  '2,449.',
#  '4,992.',
#  '745.',
#  '3,599.',
#  '1,736.',
#  '1,601.',
#  '1,719.',
#  '1,449.',
#  '745.',
#  '1,858.',
#  '1,680.',
#  '2,599.',
#  '6,775.',
#  '1,579.',
#  '1,199.',
#  '1,562.',
#  '1,500.',
#  '1,736.',
#  '1,719.',
#  '1,736.',
#  '1,039.',
#  '3,579.',
#  '1,339.',
#  '2,299.',
#  '1,819.',
#  '2,085.',
#  '1,979.',
#  '1,089.',
#  '2,129.',
#  '2,039.',
#  '1,089.',
#  '1,296.',
#  '1,562.',
#  '1,719.',
#  '1,736.',
#  '1,399.',
#  '979.',
#  '929.',
#  '2,249.',
#  '1,039.',
#  '1,039.',
#  '1,039.',
#  '1,089.',
#  '1,139.',
#  '1,109.',
#  '1,159.',
#  '1,089.',
#  '1,159.',
#  '929.',
#  '1,296.',
#  '1,562.',
#  '1,719.',
#  '1,736.',
#  '1,259.',
#  '1,039.',
#  '1,039.',
#  '1,459.',
#  '1,409.',
#  '1,459.',
#  '1,209.',
#  '1,409.',
#  '1,089.',
#  '1,159.',
#  '1,109.',
#  '1,159.',
#  '1,139.',
#  '1,109.',
#  '1,296.',
#  '1,562.',
#  '1,719.',
#  '1,736.',
#  '1,459.',
#  '1,459.',
#  '1,409.',
#  '1,959.',
#  '1,589.',
#  '1,639.',
#  '1,639.',
#  '1,809.',
#  '2,301.',
#  '1,589.',
#  '2,019.',
#  '1,549.',
#  '750.',
#  '1,404.',
#  '3,199.',
#  '899.',
#  '1,601.',
#  '1,234.',
#  '1,719.',
#  '1,736.',
#  '1,849.',
#  '2,019.',
#  '932.',
#  '1,449.',
#  '2,019.',
#  '2,929.',
#  '2,549.',
#  '2,299.',
#  '3,285.',
#  '1,296.',
#  '1,562.',
#  '1,299.',
#  '1,719.',
#  '2,299.',
#  '3,285.',
#  '1,899.',
#  '1,289.',
#  '4,149.',
#  '4,169.',
#  '3,479.',
#  '1,879.',
#  '2,301.',
#  '1,736.',
#  '1,719.',
#  '1,736.',
#  '1,729.',
#  '1,849.',
#  '4,265.',
#  '380.',
#  '1,999.',
#  '2,319.',
#  '3,599.',
#  '2,199.',
#  '1,872.',
#  '2,699.',
#  '1,160.',
#  '1,249.',
#  '2,619.',
#  '1,842.',
#  '1,296.',
#  '1,719.',
#  '1,736.',
#  '2,619.',
#  '1,296.',
#  '1,562.']
